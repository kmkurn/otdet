# %% [markdown]
# Sekarang, akan dianalisis hasil dari eksperimen besar yang menggunakan unigram sebagai fiturnya, dengan metode ```txt_comp_dist``` dan distance metric ```correlation```. Untuk setiap setting eksperimen, dilakukan 30 iterasi.

# %% [markdown]
# Import tools yang dibutuhkan dan atur agar matplotlib memplot grafik secara inline.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# Load hasil eksperimen dan tampilkan hasilnya.

# %%
df = pd.read_hdf('../reports/large-exp-uni-feat-corr-dist.h5', 'df')

# %%
df
# Out:
# num_norm                                                                 10  \
# num_oot                                                                   1
# num_top                                                                   1
# result                                                                 base
# k                                                                         0
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.909091
#                                                          mus10142  0.909091
#                                                          phy40008  0.909091
#                                                phy17301  bbs57549  0.909091
#                                                          mus10142  0.909091
#                                                          phy40008  0.909091
#                                                mus1139   bbs57549  0.909091
#                                                          mus10142  0.909091
#                                                          phy40008  0.909091
#
# num_norm                                                                     \
# num_oot
# num_top
# result
# k                                                                         1
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.090909
#                                                          mus10142  0.090909
#                                                          phy40008  0.090909
#                                                phy17301  bbs57549  0.090909
#                                                          mus10142  0.090909
#                                                          phy40008  0.090909
#                                                mus1139   bbs57549  0.090909
#                                                          mus10142  0.090909
#                                                          phy40008  0.090909
#
# num_norm                                                                     \
# num_oot
# num_top
# result                                                                 perf
# k                                                                         0
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.600000
#                                                          mus10142  0.800000
#                                                          phy40008  0.400000
#                                                phy17301  bbs57549  0.200000
#                                                          mus10142  0.600000
#                                                          phy40008  0.300000
#                                                mus1139   bbs57549  0.300000
#                                                          mus10142  0.900000
#                                                          phy40008  0.233333
#
# num_norm                                                                     \
# num_oot
# num_top
# result
# k                                                                         1
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.400000
#                                                          mus10142  0.200000
#                                                          phy40008  0.600000
#                                                phy17301  bbs57549  0.800000
#                                                          mus10142  0.400000
#                                                          phy40008  0.700000
#                                                mus1139   bbs57549  0.700000
#                                                          mus10142  0.100000
#                                                          phy40008  0.766667
#
# num_norm                                                                     \
# num_oot
# num_top                                                                   3
# result                                                                 base
# k                                                                         0
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.727273
#                                                          mus10142  0.727273
#                                                          phy40008  0.727273
#                                                phy17301  bbs57549  0.727273
#                                                          mus10142  0.727273
#                                                          phy40008  0.727273
#                                                mus1139   bbs57549  0.727273
#                                                          mus10142  0.727273
#                                                          phy40008  0.727273
#
# num_norm                                                                     \
# num_oot
# num_top
# result
# k                                                                         1
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.272727
#                                                          mus10142  0.272727
#                                                          phy40008  0.272727
#                                                phy17301  bbs57549  0.272727
#                                                          mus10142  0.272727
#                                                          phy40008  0.272727
#                                                mus1139   bbs57549  0.272727
#                                                          mus10142  0.272727
#                                                          phy40008  0.272727
#
# num_norm                                                                     \
# num_oot
# num_top
# result                                                                 perf
# k                                                                         0
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.000000
#                                                          mus10142  0.000000
#                                                          phy40008  0.000000
#                                                phy17301  bbs57549  0.000000
#                                                          mus10142  0.000000
#                                                          phy40008  0.033333
#                                                mus1139   bbs57549  0.000000
#                                                          mus10142  0.433333
#                                                          phy40008  0.000000
#
# num_norm                                                                     \
# num_oot
# num_top
# result
# k                                                                         1
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  1.000000
#                                                          mus10142  1.000000
#                                                          phy40008  1.000000
#                                                phy17301  bbs57549  1.000000
#                                                          mus10142  1.000000
#                                                          phy40008  0.966667
#                                                mus1139   bbs57549  1.000000
#                                                          mus10142  0.566667
#                                                          phy40008  1.000000
#
# num_norm                                                                     \
# num_oot
# num_top                                                                   5
# result                                                                 base
# k                                                                         0
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.545455
#                                                          mus10142  0.545455
#                                                          phy40008  0.545455
#                                                phy17301  bbs57549  0.545455
#                                                          mus10142  0.545455
#                                                          phy40008  0.545455
#                                                mus1139   bbs57549  0.545455
#                                                          mus10142  0.545455
#                                                          phy40008  0.545455
#
# num_norm                                                                     \
# num_oot
# num_top
# result
# k                                                                         1
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.454545
#                                                          mus10142  0.454545
#                                                          phy40008  0.454545
#                                                phy17301  bbs57549  0.454545
#                                                          mus10142  0.454545
#                                                          phy40008  0.454545
#                                                mus1139   bbs57549  0.454545
#                                                          mus10142  0.454545
#                                                          phy40008  0.454545
#
# num_norm                                                             ...     \
# num_oot                                                              ...
# num_top                                                              ...
# result                                                               ...
# k                                                                    ...
# method        feature max_features metric      norm_dir  oot_dir     ...
# txt_comp_dist unigram all          correlation bbs152930 bbs57549    ...
#                                                          mus10142    ...
#                                                          phy40008    ...
#                                                phy17301  bbs57549    ...
#                                                          mus10142    ...
#                                                          phy40008    ...
#                                                mus1139   bbs57549    ...
#                                                          mus10142    ...
#                                                          phy40008    ...
#
# num_norm                                                                 80  \
# num_oot                                                                   8
# num_top                                                                   5
# result                                                                 base
# k                                                                         2
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.058722
#                                                          mus10142  0.058722
#                                                          phy40008  0.058722
#                                                phy17301  bbs57549  0.058722
#                                                          mus10142  0.058722
#                                                          phy40008  0.058722
#                                                mus1139   bbs57549  0.058722
#                                                          mus10142  0.058722
#                                                          phy40008  0.058722
#
# num_norm                                                                     \
# num_oot
# num_top
# result
# k                                                                         3
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.004517
#                                                          mus10142  0.004517
#                                                          phy40008  0.004517
#                                                phy17301  bbs57549  0.004517
#                                                          mus10142  0.004517
#                                                          phy40008  0.004517
#                                                mus1139   bbs57549  0.004517
#                                                          mus10142  0.004517
#                                                          phy40008  0.004517
#
# num_norm                                                                     \
# num_oot
# num_top
# result
# k                                                                         4
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.000143
#                                                          mus10142  0.000143
#                                                          phy40008  0.000143
#                                                phy17301  bbs57549  0.000143
#                                                          mus10142  0.000143
#                                                          phy40008  0.000143
#                                                mus1139   bbs57549  0.000143
#                                                          mus10142  0.000143
#                                                          phy40008  0.000143
#
# num_norm                                                                     \
# num_oot
# num_top
# result
# k                                                                         5
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.000001
#                                                          mus10142  0.000001
#                                                          phy40008  0.000001
#                                                phy17301  bbs57549  0.000001
#                                                          mus10142  0.000001
#                                                          phy40008  0.000001
#                                                mus1139   bbs57549  0.000001
#                                                          mus10142  0.000001
#                                                          phy40008  0.000001
#
# num_norm                                                                     \
# num_oot
# num_top
# result                                                                 perf
# k                                                                         0
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.000000
#                                                          mus10142  0.000000
#                                                          phy40008  0.000000
#                                                phy17301  bbs57549  0.000000
#                                                          mus10142  0.000000
#                                                          phy40008  0.033333
#                                                mus1139   bbs57549  0.033333
#                                                          mus10142  0.433333
#                                                          phy40008  0.233333
#
# num_norm                                                                     \
# num_oot
# num_top
# result
# k                                                                         1
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.000000
#                                                          mus10142  0.000000
#                                                          phy40008  0.000000
#                                                phy17301  bbs57549  0.000000
#                                                          mus10142  0.000000
#                                                          phy40008  0.166667
#                                                mus1139   bbs57549  0.266667
#                                                          mus10142  0.466667
#                                                          phy40008  0.400000
#
# num_norm                                                                     \
# num_oot
# num_top
# result
# k                                                                         2
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.000000
#                                                          mus10142  0.000000
#                                                          phy40008  0.000000
#                                                phy17301  bbs57549  0.000000
#                                                          mus10142  0.133333
#                                                          phy40008  0.300000
#                                                mus1139   bbs57549  0.200000
#                                                          mus10142  0.100000
#                                                          phy40008  0.100000
#
# num_norm                                                                     \
# num_oot
# num_top
# result
# k                                                                         3
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.233333
#                                                          mus10142  0.000000
#                                                          phy40008  0.000000
#                                                phy17301  bbs57549  0.033333
#                                                          mus10142  0.233333
#                                                          phy40008  0.400000
#                                                mus1139   bbs57549  0.266667
#                                                          mus10142  0.000000
#                                                          phy40008  0.200000
#
# num_norm                                                                     \
# num_oot
# num_top
# result
# k                                                                         4
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.766667
#                                                          mus10142  0.700000
#                                                          phy40008  0.600000
#                                                phy17301  bbs57549  0.300000
#                                                          mus10142  0.433333
#                                                          phy40008  0.100000
#                                                mus1139   bbs57549  0.133333
#                                                          mus10142  0.000000
#                                                          phy40008  0.066667
#
# num_norm
# num_oot
# num_top
# result
# k                                                                         5
# method        feature max_features metric      norm_dir  oot_dir
# txt_comp_dist unigram all          correlation bbs152930 bbs57549  0.000000
#                                                          mus10142  0.300000
#                                                          phy40008  0.400000
#                                                phy17301  bbs57549  0.666667
#                                                          mus10142  0.200000
#                                                          phy40008  0.000000
#                                                mus1139   bbs57549  0.100000
#                                                          mus10142  0.000000
#                                                          phy40008  0.000000
#
# [9 rows x 116 columns]

# %% [markdown]
# Hitung rata-rata hasil terhadap seluruh dataset.

# %%
df2 = df.groupby(level='feature').mean()

# %%
df2
# Out:
# num_norm        10                                                    \
# num_oot          1
# num_top          1                                       3
# result        base                perf                base
# k                0         1         0         1         0         1
# feature
# unigram   0.909091  0.090909  0.481481  0.518519  0.727273  0.272727
#
# num_norm                                            ...           80  \
# num_oot                                             ...            8
# num_top                              5              ...            5
# result        perf                base              ...         base
# k                0         1         0         1    ...            2
# feature                                             ...
# unigram   0.051852  0.948148  0.545455  0.454545    ...     0.058722
#
# num_norm                                                              \
# num_oot
# num_top
# result                                      perf
# k                3         4         5         0         1         2
# feature
# unigram   0.004517  0.000143  0.000001  0.081481  0.144444  0.092593
#
# num_norm
# num_oot
# num_top
# result
# k                3         4         5
# feature
# unigram   0.151852  0.344444  0.185185
#
# [1 rows x 116 columns]

# %% [markdown]
# Karena lebih mudah scroll secara vertikal, tampilkan transposnya.

# %%
df2.T
# Out:
# feature                             unigram
# num_norm num_oot num_top result k
# 10       1       1       base   0  0.909091
#                                 1  0.090909
#                          perf   0  0.481481
#                                 1  0.518519
#                  3       base   0  0.727273
#                                 1  0.272727
#                          perf   0  0.051852
#                                 1  0.948148
#                  5       base   0  0.545455
#                                 1  0.454545
#                          perf   0  0.044444
#                                 1  0.955556
#          4       1       base   0  0.714286
#                                 1  0.285714
#                          perf   0  0.359259
#                                 1  0.640741
#                  3       base   0  0.329670
#                                 1  0.494505
#                                 2  0.164835
#                                 3  0.010989
#                          perf   0  0.022222
#                                 1  0.237037
#                                 2  0.637037
#                                 3  0.103704
#                  5       base   0  0.125874
#                                 1  0.419580
#                                 2  0.359640
#                                 3  0.089910
#                                 4  0.004995
#                          perf   0  0.000000
# ...                                     ...
# 80       4       5       base   4  0.000003
#                          perf   0  0.107407
#                                 1  0.162963
#                                 2  0.214815
#                                 3  0.270370
#                                 4  0.244444
#          8       1       base   0  0.909091
#                                 1  0.090909
#                          perf   0  0.192593
#                                 1  0.807407
#                  3       base   0  0.748706
#                                 1  0.230371
#                                 2  0.020413
#                                 3  0.000510
#                          perf   0  0.085185
#                                 1  0.129630
#                                 2  0.329630
#                                 3  0.455556
#                  5       base   0  0.613645
#                                 1  0.322971
#                                 2  0.058722
#                                 3  0.004517
#                                 4  0.000143
#                                 5  0.000001
#                          perf   0  0.081481
#                                 1  0.144444
#                                 2  0.092593
#                                 3  0.151852
#                                 4  0.344444
#                                 5  0.185185
#
# [116 rows x 1 columns]

# %% [markdown]
# Letakkan baseline dan hasil eksperimen bersisian sehingga mudah dibandingkan.

# %%
df3 = df2.T.unstack(level='result')

# %%
df3
# Out:
# feature                      unigram
# result                          base      perf
# num_norm num_oot num_top k
# 10       1       1       0  0.909091  0.481481
#                          1  0.090909  0.518519
#                  3       0  0.727273  0.051852
#                          1  0.272727  0.948148
#                  5       0  0.545455  0.044444
#                          1  0.454545  0.955556
#          4       1       0  0.714286  0.359259
#                          1  0.285714  0.640741
#                  3       0  0.329670  0.022222
#                          1  0.494505  0.237037
#                          2  0.164835  0.637037
#                          3  0.010989  0.103704
#                  5       0  0.125874  0.000000
#                          1  0.419580  0.066667
#                          2  0.359640  0.159259
#                          3  0.089910  0.522222
#                          4  0.004995  0.251852
#          8       1       0  0.555556  0.481481
#                          1  0.444444  0.518519
#                  3       0  0.147059  0.007407
#                          1  0.441176  0.266667
#                          2  0.343137  0.585185
#                          3  0.068627  0.140741
#                  5       0  0.029412  0.000000
#                          1  0.196078  0.066667
#                          2  0.392157  0.133333
#                          3  0.294118  0.381481
#                          4  0.081699  0.388889
#                          5  0.006536  0.029630
# 80       1       1       0  0.987654  0.496296
#                          1  0.012346  0.503704
#                  3       0  0.962963  0.322222
#                          1  0.037037  0.677778
#                  5       0  0.938272  0.300000
#                          1  0.061728  0.700000
#          4       1       0  0.952381  0.207407
#                          1  0.047619  0.792593
#                  3       0  0.862264  0.140741
#                          1  0.132656  0.214815
#                          2  0.005038  0.370370
#                          3  0.000042  0.274074
#                  5       0  0.778699  0.107407
#                          1  0.204921  0.162963
#                          2  0.015968  0.214815
#                          3  0.000409  0.270370
#                          4  0.000003  0.244444
#          8       1       0  0.909091  0.192593
#                          1  0.090909  0.807407
#                  3       0  0.748706  0.085185
#                          1  0.230371  0.129630
#                          2  0.020413  0.329630
#                          3  0.000510  0.455556
#                  5       0  0.613645  0.081481
#                          1  0.322971  0.144444
#                          2  0.058722  0.092593
#                          3  0.004517  0.151852
#                          4  0.000143  0.344444
#                          5  0.000001  0.185185

# %% [markdown]
# Sedikit penjelasan, ```k``` menyatakan banyaknya OOT posts yang terambil pada top list.

# %% [markdown]
# Agar lebih jelas, akan diplot hasil untuk setiap kejadian acak yang ditandai dengan ```(num_norm, num_oot, num_top)``` yang berbeda.

# %%
grouped = df3.groupby(level=['num_norm', 'num_oot', 'num_top'])

# %% [markdown]
# Pada plot di bawah ini, warna biru dan hijau menyatakan histogram baseline dan hasil eksperimen berturut-turut.

# %%
for name, group in grouped:
    group.plot(kind='bar', legend=False, use_index=False, title='num_norm={}, num_oot={}, num_top={}'.format(*name))

# %% [markdown]
# Dapat dilihat dari grafik di atas bahwa hasil eksperimen jauh lebih baik ketimbang baseline. Untuk lebih jelasnya lagi, akan lebih mudah apabila kita dapat menyatakan setiap distribusi/histogram dalam satu buah angka pengukuran. Untuk keperluan ini, angka pengukuran yang akan digunakan adalah expected value/rata-rata.

# %%
ngroup = len(grouped)
data = np.empty((ngroup, 2))
index = []
for i, (name, _) in enumerate(grouped):
    tmp = df3.loc[name]
    prod = tmp.T * np.array(tmp.index)   # multiply pmf and support
    prod = prod.unstack(level='result')
    expval = prod.sum(axis=1, level='result').values.ravel()
    data[i,:] = expval
    index.append(name)

# %%
data
# Out:
# array([[ 0.09090909,  0.51851852],
#        [ 0.27272727,  0.94814815],
#        [ 0.45454545,  0.95555556],
#        [ 0.28571429,  0.64074074],
#        [ 0.85714286,  1.82222222],
#        [ 1.42857143,  2.95925926],
#        [ 0.44444444,  0.51851852],
#        [ 1.33333333,  1.85925926],
#        [ 2.22222222,  3.18148148],
#        [ 0.01234568,  0.5037037 ],
#        [ 0.03703704,  0.67777778],
#        [ 0.0617284 ,  0.7       ],
#        [ 0.04761905,  0.79259259],
#        [ 0.14285714,  1.77777778],
#        [ 0.23809524,  2.38148148],
#        [ 0.09090909,  0.80740741],
#        [ 0.27272727,  2.15555556],
#        [ 0.45454545,  3.08888889]])

# %%
index = pd.MultiIndex.from_tuples(index, names=['num_norm', 'num_oot', 'num_top'])
columns = pd.MultiIndex.from_tuples([('E[X]', 'base'), ('E[X]', 'perf')])

# %%
result = pd.DataFrame(data, index=index, columns=columns)

# %%
result
# Out:
#                               E[X]
#                               base      perf
# num_norm num_oot num_top
# 10       1       1        0.090909  0.518519
#                  3        0.272727  0.948148
#                  5        0.454545  0.955556
#          4       1        0.285714  0.640741
#                  3        0.857143  1.822222
#                  5        1.428571  2.959259
#          8       1        0.444444  0.518519
#                  3        1.333333  1.859259
#                  5        2.222222  3.181481
# 80       1       1        0.012346  0.503704
#                  3        0.037037  0.677778
#                  5        0.061728  0.700000
#          4       1        0.047619  0.792593
#                  3        0.142857  1.777778
#                  5        0.238095  2.381481
#          8       1        0.090909  0.807407
#                  3        0.272727  2.155556
#                  5        0.454545  3.088889

# %% [markdown]
# Tabel di atas menunjukkan expected value baseline dan hasil eksperimen dengan metode ```txt_comp_dist``` untuk masing-masing kejadian acak. Terlihat bahwa hasil eksperimen dengan metode ```txt_comp_dist``` jauh mengungguli baseline.
